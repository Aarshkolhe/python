# %%
dict1={x:x**2 for x in range (0,10)}
print(dict1)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %%
print(dict1[5])
# Out:
# 25

# %%
dict1[11]=121
print(dict1)

del dict1[1]
print(dict1)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 11: 121}
# {0: 0, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 11: 121}

# %%
for key,value in dict1.items():
    print(key,value)
# Out:
# 0 0
# 2 4
# 3 9
# 4 16
# 5 25
# 6 36
# 7 49
# 8 64
# 9 81
# 11 121

# %%
dict2={y:y**3 for y in range (0,11)}
print(dict2)
# Out:
# {0: 0, 1: 1, 2: 8, 3: 27, 4: 64, 5: 125, 6: 216, 7: 343, 8: 512, 9: 729, 10: 1000}

# %%
dict3={x:x**2 for x in range (0,6)}
dict4={x:x**2 for x in range (6,11)}
print(dict3)
print(dict4)
dict3.update(dict4)
print(dict3)
print(dict4)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# {6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# {6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
dict5={
    "name" :"Aryan",
    "age":"18",
    "grade":{"math":100,"science":100,"english":100}
    
}
print(dict5)
# Out:
# 100

# %%
dict6={x:x*5 for x in range(0,6)}
print(dict6)
tuple1 = tuple(dict6.items())
print(tuple1)
# Out:
# {0: 0, 1: 5, 2: 10, 3: 15, 4: 20, 5: 25}
# ((0, 0), (1, 5), (2, 10), (3, 15), (4, 20), (5, 25))

# %%
dict7={x:(x,x**2) for x in range(0,6)}
print(dict7)
# Out:
# {0: (0, 0), 1: (1, 1), 2: (2, 4), 3: (3, 9), 4: (4, 16), 5: (5, 25)}

# %%
dict8={x:x**2 for x in range(0,11)}
print(dict8)
dict9={key:value for key,value in dict8.items() if (key%2==0)}
print(dict9)
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# {0: 0, 2: 4, 4: 16, 6: 36, 8: 64, 10: 100}

# %%
dict10={x:x**2 for x in range(0,6) }
print(dict10)
dict11={key:value for key,value in dict}
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
dict11={x:x**2 for x in range (1,6)}
print(dict11)
dict12={value:key for key,value in dict11.items()}
print(dict12)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
# {1: 1, 4: 2, 9: 3, 16: 4, 25: 5}

# %%
def count(name):
          dic13={nam:(name.index(nam)+1) for nam in name}
          print(dic13)
count("ganesh")
# Out:
# {'g': 1, 'a': 2, 'n': 3, 'e': 4, 's': 5, 'h': 6}

# %%
import json

book={"title":"world","author":"lord","year":"2025","genre":"supernatural"}

json_string=json.dumps(book)
print(json_string)
# Out:
# {"title": "world", "author": "lord", "year": "2025", "genre": "supernatural"}
